# %%
def minha_soma(n1, n2, n3):
      return n1 + n2 + n3
n1 = int(input('Digite o número: '))
n2 = int(input('Digite o número: '))
n3 = int(input('Digite o número: '))
soma = minha_soma(n1, n2, n3)
print(f'A soma dos Parametros é {soma}')
# Out:
# A soma dos Parametros é 30
